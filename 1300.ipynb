# %%
from jupyter_graphs import create_graphs
from bokeh.plotting import show
from bokeh.io import output_notebook
output_notebook()
plots = create_graphs(sim_num=1300)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="5dfc2ec4-fc57-43ea-9342-f1a2df3f20e6">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # CIFAR10 - Asynchronous with 10 workers
# ## wide resnet - depth 28 , widen factor 2

# %% [markdown]
#       sim_num: 1300
#       epochs: 200
#       batch_size: 128
#       learning_rate: [[0.1, 0.02, 0.004, 0.0008],[1, 60, 120, 160]]
#       gradient_clipping: 5
#       momentum: 0.9
#       weight_decay: 0.0005

# %%
show(plots[0])
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="3e429b1c-8eb0-461d-8ee2-691dc9bf7c98"></div>
# </div>

# %%
show(plots[1])
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="267752e1-3711-49fd-bf8f-47cc00deb6d0"></div>
# </div>

# %%
show(plots[2])
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="a3441b37-72e9-43b6-a0d5-a1b5fca0f300"></div>
# </div>

# %%
show(plots[3])
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="e2f03a07-dd1f-435b-8946-a948539a4c23"></div>
# </div>
