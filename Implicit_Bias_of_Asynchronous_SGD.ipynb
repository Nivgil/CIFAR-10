# %% [markdown]
# # Implicit Bias of Asynchronous SGD

# %%
from jupyter_graphs import create_graphs
from bokeh.plotting import show, output_notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="409aa348-7f14-48fa-a96c-aabac107c4fd">Loading BokehJS ...</span>
#     </div>

# %%
sim_num = 203
variable = 'optimizer'
resolution = 'epoch'
plots = create_graphs(sim_num, variable, resolution)

# %%
show(plots[0])
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="1af6e36b-67a7-43ea-a029-076e3ec870ea"></div>
# </div>

# %%
show(plots[1])
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="1208ef61-a060-46a9-aeeb-93f4d672bd74"></div>
# </div>
