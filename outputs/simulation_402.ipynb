# %%
from jupyter_graphs import create_graphs
from bokeh.plotting import show
from bokeh.io import output_notebook
output_notebook()
plots = create_graphs(sim_num=402)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="b1036a6d-29ab-45ea-b64e-5f5bb34d668d">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # CIFAR 100 - Asynchronous with high number of workers

# %% [markdown]
# Batch size - 128 <br>
# Gradient clipping threshold 0.8  <br>
# Resnet depth 56  <br>
# Comparing 1, 100 & 200 workers

# %%
show(plots[0])
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="ab3bb669-a7d6-4c64-bf95-679bb8ff9bcf"></div>
# </div>

# %%
show(plots[1])
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="e3506e43-205d-474e-9fe9-e8ea52179717"></div>
# </div>

# %%
show(plots[2])
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="14aa3ecd-f7a2-4e00-aa28-e433620de37d"></div>
# </div>

# %%
show(plots[3])
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="57bbf577-58d5-412a-b320-a6048648fbf1"></div>
# </div>
