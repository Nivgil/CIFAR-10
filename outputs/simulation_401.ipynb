# %%
from jupyter_graphs import create_graphs
from bokeh.plotting import show
from bokeh.io import output_notebook
output_notebook()
plots = create_graphs(sim_num=401)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="c7cddf1d-8f21-4efc-b1b3-093662747b70">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # CIFAR 10 - Asynchronous with high number of workers

# %% [markdown]
# Batch size - 128 <br>
# Gradient clipping threshold 0.8 <br>
# Resnet depth 56 <br>
# Comparing 1, 100 & 200 workers

# %%
show(plots[0])
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="06916e57-a55d-4b53-b2bd-669a6d5f1aa0"></div>
# </div>

# %%
show(plots[1])
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="e9bdca5e-48fa-42fe-8b5f-047951f7fc41"></div>
# </div>

# %%
show(plots[2])
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="8494b1e0-2027-42ba-9ab0-be34ca8b5d36"></div>
# </div>

# %%
show(plots[3])
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="b034979c-9d83-4894-a403-86338b868fc2"></div>
# </div>
