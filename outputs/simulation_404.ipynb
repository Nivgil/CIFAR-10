# %%
from jupyter_graphs import create_graphs
from bokeh.plotting import show
from bokeh.io import output_notebook
output_notebook()
plots = create_graphs(sim_num=404)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="9e57b570-6668-47eb-933c-1d0cc256edcc">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # CIFAR 100 - Asynchronous with high number of workers
# ## Wide residual network

# %% [markdown]
# Batch size - 128 <br>
# No gradient clipping <br>
# Wide resnet depth 28, k-factor - 4  <br>
# Comparing 1, 100 & 200 workers

# %%
show(plots[0])
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="aac4a1ad-9f14-4379-9e80-71f07aa640f5"></div>
# </div>

# %%
show(plots[1])
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="1ad299a4-0f47-486e-b3ce-9d67647d95e9"></div>
# </div>

# %%
show(plots[2])
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="ab20b628-9716-43c0-96ae-0c28beaf5bb2"></div>
# </div>

# %%
show(plots[3])
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="75d25ebf-e01f-4ee0-8cdc-8ab430e07c41"></div>
# </div>
